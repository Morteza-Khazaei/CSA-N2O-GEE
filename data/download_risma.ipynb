# %% [markdown]
# ## Import RismaData as it is a part of inversion package

# %%
from inversion import RismaData

# %%
risma = RismaData(workspace_dir='../assets', )
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Found RISMA_CSV folder: RISMA_CSV_files
# RISMA_CSV folder already exists: ../assets/inputs/RISMA_CSV_files

# %%
risma_stations = ['RISMA_MB1', 'RISMA_MB2', 'RISMA_MB3', 'RISMA_MB4', 
                  'RISMA_MB5', 'RISMA_MB6', 'RISMA_MB7', 'RISMA_MB8', 
                  'RISMA_MB9', 'RISMA_MB10', 'RISMA_MB11', 'RISMA_MB12', 
                  'RISMA_MB13']
params = ['Air Temp', 'Soil temperature', 'Soil Moisture']
sensors= 'average'
depths = ['0 to 5 cm', '5 cm']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
risma.download_risma_data(
    out_dir='../assets/inputs/RISMA_CSV_files', 
    stations=risma_stations, parameters=params, 
    sensors=sensors, depths=depths, 
    start_date='2023-01-01', end_date='2024-01-01')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB1_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB1.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB10_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB10.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB11_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB11.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB12_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB12.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB13_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB13.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB2_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB2.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB3_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB3.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB4_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB4.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB5_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB5.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB6_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB6.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB7_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB7.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB8_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB8.
# The file '../assets/inputs/RISMA_CSV_files/RISMA_MB9_2023_to_2024.csv' exists.
# 	Skipping download process for RISMA_MB9.

# %%
risma_df = risma.load_df()
print(risma_df.shape)
risma_df.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 	Processing file: RISMA_MB1_2023_to_2024.csv
# 	Processing file: RISMA_MB2_2023_to_2024.csv
# 	Processing file: RISMA_MB3_2023_to_2024.csv
# 	Processing file: RISMA_MB4_2023_to_2024.csv
# 	Processing file: RISMA_MB5_2023_to_2024.csv
# 	Processing file: RISMA_MB6_2023_to_2024.csv
# 	Processing file: RISMA_MB7_2023_to_2024.csv
# 	Processing file: RISMA_MB8_2023_to_2024.csv
# 	Processing file: RISMA_MB9_2023_to_2024.csv
# 	Processing file: RISMA_MB10_2023_to_2024.csv
# 	Processing file: RISMA_MB11_2023_to_2024.csv
# 	Processing file: RISMA_MB12_2023_to_2024.csv
# 	Processing file: RISMA_MB13_2023_to_2024.csv
# (8746, 17)
#         date station      depth  op  mean_sst  mean_airt       SSM       SST  \
# 0 2023-01-01     MB1  0 to 5 cm   0    -2.415     -9.000  0.087333 -2.356667
# 1 2023-01-01     MB1  0 to 5 cm   1    -2.415     -9.000  0.087778 -2.478889
# 2 2023-01-01    MB10  0 to 5 cm   0     6.125     -8.205  0.810000  6.097778
# 3 2023-01-01    MB10  0 to 5 cm   1     6.125     -8.205  0.800000  6.141111
# 4 2023-01-01    MB11  0 to 5 cm   0    -2.450     -7.780  0.240000 -2.361111
#
#    year  doy Station  Depth (cm)  bulk    Sand   Silt   Clay Classification
# 0  2023    1     MB1           5  1.28  0.7880  0.101  0.111     Sandy Loam
# 1  2023    1     MB1           5  1.28  0.7880  0.101  0.111     Sandy Loam
# 2  2023    1    MB10           5  1.05  0.0455  0.240  0.716     Heavy Clay
# 3  2023    1    MB10           5  1.05  0.0455  0.240  0.716     Heavy Clay
# 4  2023    1    MB11           5  1.30  0.2380  0.395  0.368      Clay Loam
